# %% [markdown]
# # 1. Enable GPU access in the notebook

# %% [markdown]
# # **Runtime → Change runtime type → T4 GPU**

# %% [markdown]
# # 2. Install reflectorch (from PyPi or Github)

# %%
import locale


def getpreferredencoding(do_setlocale=True):
    return "UTF-8"


locale.getpreferredencoding = (
    getpreferredencoding  # ensure that Google Colab works with shell commands
)

# !pip install reflectorch
#!pip install git+https://github.com/schreiber-lab/reflectorch.git
# Out:
# Requirement already satisfied: reflectorch in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: numpy<2.0,>=1.18.1 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from reflectorch) (1.26.4)
# Requirement already satisfied: torch>=1.8.1 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from reflectorch) (2.6.0)
# Requirement already satisfied: scipy in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from reflectorch) (1.15.2)
# Requirement already satisfied: tqdm in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from reflectorch) (4.67.1)
# Requirement already satisfied: PyYAML in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from reflectorch) (6.0.2)
# Requirement already satisfied: click in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from reflectorch) (8.1.8)
# Requirement already satisfied: matplotlib in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from reflectorch) (3.10.1)
# Requirement already satisfied: ipywidgets in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from reflectorch) (8.1.5)
# Requirement already satisfied: huggingface-hub in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from reflectorch) (0.29.3)
# Requirement already satisfied: safetensors in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from reflectorch) (0.5.3)
# Requirement already satisfied: filelock in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (4.12.2)
# Requirement already satisfied: networkx in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (3.1.6)
# Requirement already satisfied: fsspec in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (3.2.0)
# Requirement already satisfied: setuptools in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (76.0.0)
# Requirement already satisfied: sympy==1.13.1 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from torch>=1.8.1->reflectorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.8.1->reflectorch) (1.3.0)
# Requirement already satisfied: packaging>=20.9 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from huggingface-hub->reflectorch) (24.2)
# Requirement already satisfied: requests in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from huggingface-hub->reflectorch) (2.32.3)
# Requirement already satisfied: comm>=0.1.3 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from ipywidgets->reflectorch) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from ipywidgets->reflectorch) (9.0.2)
# Requirement already satisfied: traitlets>=4.3.1 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from ipywidgets->reflectorch) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from ipywidgets->reflectorch) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from ipywidgets->reflectorch) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from matplotlib->reflectorch) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from matplotlib->reflectorch) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from matplotlib->reflectorch) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from matplotlib->reflectorch) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from matplotlib->reflectorch) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from matplotlib->reflectorch) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from matplotlib->reflectorch) (2.9.0.post0)
# Requirement already satisfied: decorator in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->reflectorch) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->reflectorch) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->reflectorch) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->reflectorch) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->reflectorch) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->reflectorch) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->reflectorch) (2.19.1)
# Requirement already satisfied: stack_data in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->reflectorch) (0.6.3)
# Requirement already satisfied: six>=1.5 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->reflectorch) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from jinja2->torch>=1.8.1->reflectorch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from requests->huggingface-hub->reflectorch) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from requests->huggingface-hub->reflectorch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from requests->huggingface-hub->reflectorch) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from requests->huggingface-hub->reflectorch) (2025.1.31)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->reflectorch) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->reflectorch) (0.7.0)
# Requirement already satisfied: wcwidth in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->reflectorch) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->reflectorch) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->reflectorch) (3.0.0)
# Requirement already satisfied: pure-eval in /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->reflectorch) (0.2.3)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # 3. Imports

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import torch

from ipywidgets import widgets, interact
from pathlib import Path
from reflectorch import *
from reflectorch.extensions.jupyter import JPlotLoss

torch.manual_seed(0)  # set seed for reproducibility

# %% [markdown]
# # 4. How to train a model

# %% [markdown]
# The default paths for storing the configuration files and the model weights are relative to the package installation directory.

# %%
print(CONFIG_DIR, "\n", SAVED_MODELS_DIR)
# Out:
# /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages/configs
#  /home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages/saved_models

# %% [markdown]
# In the following we will create new locations for storing the configuration files and model weights, relative to our current working directory.

# %%
# !mkdir configs
# !mkdir saved_models
# !ls
# Out:
# mkdir: cannot create directory ‘configs’: File exists
# mkdir: cannot create directory ‘saved_models’: File exists
# configs   explore_reflectorch.ipynb  Pipfile	   saved_models
# exp_data  helloworld.ipynb	     Pipfile.lock

# %% [markdown]
# We will download a sample configuration file from the Github repository and store it in the configuration directory.

# %%
config_name = "c1"
download_link = f"https://raw.githubusercontent.com/schreiber-lab/reflectorch/master/configs/{config_name}.yaml"
print(download_link)

# Download the configuration file
# !wget -N -P ./configs/ $download_link

# List the contents of the configs directory
# !ls -l ./configs/
# Out:
# https://raw.githubusercontent.com/schreiber-lab/reflectorch/master/configs/c1.yaml
# --2025-05-02 12:36:15--  https://raw.githubusercontent.com/schreiber-lab/reflectorch/master/configs/c1.yaml
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2243 (2,2K) [text/plain]
# Saving to: ‘./configs/c1.yaml’
#
# c1.yaml             100%[===================>]   2,19K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-05-02 12:36:15 (38,8 MB/s) - ‘./configs/c1.yaml’ saved [2243/2243]
#
# total 12
# -rw-r--r-- 1 levytskyi levytskyi 5722 14. Apr 11:32 'c1 copy.yaml'
# -rw-r--r-- 1 levytskyi levytskyi 2243  2. Mai 12:36  c1.yaml

# %% [markdown]
# For training a model we use the `Trainer` class, which contains all the components necessary for the training process such as the data generator, the neural network and the optimizer.
#
#  We can initialize the trainer according to the specifications defined in a YAML configuration file using the `get_trainer_by_name` method which takes as input the name of the configuration file. If the package was installed in editable model, the configuration files are read from the `configs` directory located inside the repository, otherwise the path to the directory containing the configuration file should also be specified using the `config_dir`
#  argument. The `load_weights` argument should be set to `False` since we want the neural network weights to be randomly initialized for a fresh training.

# %% [markdown]
# **Note**: for training on the CPU, all the `device` arguments in the configuration file would have to be changed to `cpu` instead of `cuda`.

# %%
trainer = get_trainer_by_name(
    config_name="c1", config_dir="configs/", load_weights=False
)  # note: /content/ is the root of the Google Colab filesystem
# Out:
# Model c1 loaded. Number of parameters: 3.83 M

# %% [markdown]
# The trainer contains several important attributes we can inspect:

# %% [markdown]
#   1. The Pytorch optimizer:

# %%
trainer.optim
# Out:
# AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: [0.9, 0.999]
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.0005
# )

# %% [markdown]
#   2. The batch size:

# %%
trainer.batch_size
# Out:
# 4096

# %% [markdown]
#   3. The Pytorch neural network module. We can see that the network is an instance of the class `PriorInformedNetworkConvEmb`. This architecture consists of a multilayer perceptron (MLP) with residual connections, batch normalization layers and GELU activations (`trainer.model.mlp`). A 1D CNN embedding network (`trainer.model.embedding_net`) produces a latent embedding of the input batch of reflectivity curves which is concatenated with the prior bounds for the thin film parameters.

# %%
trainer.model
# Out:
# NetworkWithPriorsConvEmb(
#   (embedding_net): ConvEncoder(
#     (core): Sequential(
#       (0): Sequential(
#         (0): Conv1d(1, 32, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): GELU(approximate='none')
#       )
#       (1): Sequential(
#         (0): Conv1d(32, 64, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): GELU(approximate='none')
#       )
#       (2): Sequential(
#         (0): Conv1d(64, 128, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): GELU(approximate='none')
#       )
#       (3): Sequential(
#         (0): Conv1d(128, 256, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): GELU(approximate='none')
#       )
#       (4): Sequential(
#         (0): Conv1d(256, 512, kernel_size=(3,), stride=(2,), padding=(1,))
#         (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): GELU(approximate='none')
#       )
#     )
#     (avpool): AdaptiveAvgPool1d(output_size=1)
#     (fc): Linear(in_features=512, out_features=128, bias=True)
#   )
#   (mlp): ResidualMLP(
#     (first_layer): Linear(in_features=144, out_features=512, bias=True)
#     (blocks): ModuleList(
#       (0-5): 6 x ResidualBlock(
#         (activation): GELU(approximate='none')
#         (batch_norm_layers): ModuleList(
#           (0-1): 2 x BatchNorm1d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (linear_layers): ModuleList(
#           (0-1): 2 x Linear(in_features=512, out_features=512, bias=True)
#         )
#       )
#     )
#     (last_layer): Linear(in_features=512, out_features=8, bias=True)
#   )
# )

# %% [markdown]
# We can control the training process using callback objects, such as:

# %% [markdown]
#   1. `JPlotLoss` - allows the interactive visualization of the loss curve when training inside a Jupyter Notebook, the `frequency` argument setting the refresh rate of the interactive widget

# %% [markdown]
#   2. `StepLR` - implements a learning rate scheduler which decreases the learning rate in steps (after a number of iterations defined by `step_size` the learning rate is multiplied by the factor `gamma`). Other types of learning rate schedulers can alternatively be used, such as `CyclicLR`, `LogCyclicLR`, `OneCycleLR` or `ReduceLROnPlateau`.

# %% [markdown]
#   3. `SaveBestModel` - it enables the periodic saving of the weights of the neural network during training. After a number of iterations defined by the `freq` argument, the weights of the neural network are saved at the specified `path` if the current average loss (computed over the last `average` iterations) is lower than the loss for the previous save. The history of the losses and learning rate values is also saved.

# %% [markdown]
# We defined a callback for saving model weights in the previously created `saved_models` directory and we group the callback objects together in a tuple:

# %%
print(Path("saved_models").absolute())

save_model_name = "model_" + config_name + ".pt"
save_path = str(Path("saved_models") / save_model_name)  #

callbacks = (
    JPlotLoss(frequency=10),
    StepLR(step_size=5000, gamma=0.1, last_epoch=-1),
    SaveBestModel(path=save_path, freq=100, average=10),
)
# Out:
# /home/levytskyi/Documents/reflectorch api playground/saved_models

# %% [markdown]
# The training process is initiated by calling the `train` method of the trainer. This method accepts as arguments the previously defined tuple of callbacks, as well as the number of iterations (batches). Notably, a new batch of data is generated at each iteration, the training taking place in a "one-epoch regime".

# %%
# We train for a small number of iterations just for testing the functionality. Training for extended amount in Google Colab will exhaust you limited allocated resources.

trainer.train(num_batches=500, callbacks=callbacks)

# %% [markdown]
# We can check that the model weights have been saved in the directory:

# %%
torch.load(save_path, weights_only=False).keys()
# Out:
# dict_keys(['model', 'lrs', 'losses', 'prev_save', 'batch_num', 'best_loss'])

# %% [markdown]
# # 5. How to use a trained model for inference

# %% [markdown]
# The `EasyInferenceModel` class simplifies the inference step for single reflectivity curves. We initialize the inference model by providing the name of the configuration file of a pretrained model (`config_name`), either with or without the '.yaml' extension. By default, the file name of the saved model weights for a specific configuration has the format 'model_' + config_name + '.safetensors', but a different file name can be specified via the `model_name` argument. The `root_dir` argument can be used to specify a project directory containing the `configs` and `saved_models` subdirectories (containing the configurations and model weights, respectively), if different from the default package directory. If the configuration or weights files are not found locally, they can be downloaded automatically from the Huggingface repository specified with the `repo_id` argument. Additionally, the `device` argument can be set to either `cuda` (for inference on the GPU) or `cpu` (for computers without a GPU with CUDA support).

# %% [markdown]
# We create and instance of the inference class, which also prints some details about the model such as the parameter ranges.
#
# The configuration and weight files are not found locally so they are automatically downloaded from Huggingface.
#
# Notably, here we specify a new root directory (which should contain the `configs` and `saved_models` directories), which is specific to the Google Colab filesystem.

# %%
inference_model = EasyInferenceModel(
    config_name="mc25",
    model_name=None,  # since the model weight file satisfies the naming format 'model_' + config_name + '.safetensors'
    # root_dir='/', #specific to Google Colab
    repo_id="valentinsingularity/reflectivity",
    device="cuda",
)
# Out:
# Configuration file `/home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages/configs/mc25.yaml` found locally.
# Weights file `/home/levytskyi/.local/share/virtualenvs/reflectorch_api_playground-51z8QqIg/lib/python3.12/site-packages/saved_models/model_mc25.safetensors` found locally.
# Model mc25 loaded. Number of parameters: 13.37 M
# The model corresponds to a `standard_model` parameterization with 2 layers (8 predicted parameters)
# Parameter types and total ranges:
# - thicknesses: [0.0, 500.0]
# - roughnesses: [0.0, 20.0]
# - slds: [0.0, 50.0]
# Allowed widths of the prior bound intervals (max-min):
# - thicknesses: [0.01, 500.0]
# - roughnesses: [0.01, 20.0]
# - slds: [0.01, 5.0]
# The model was trained on curves discretized at 128 uniform points between between q_min=0.02 and q_max=0.15

# %% [markdown]
# We download some sample reflectity data inside our local `exp_data` directory.

# %%
# Create the data directory if it does not exist
# !mkdir -p exp_data

# Download the file
download_link = "https://raw.githubusercontent.com/schreiber-lab/reflectorch/master/exp_data/data_PTCDI-C3.txt"
print(download_link)
# !wget -N -P ./exp_data/ $download_link

# List the contents of the exp_data directory
# !ls ./exp_data/
# Out:
# https://raw.githubusercontent.com/schreiber-lab/reflectorch/master/exp_data/data_PTCDI-C3.txt
# --2025-04-04 10:39:38--  https://raw.githubusercontent.com/schreiber-lab/reflectorch/master/exp_data/data_PTCDI-C3.txt
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4239 (4,1K) [text/plain]
# Saving to: ‘./exp_data/data_PTCDI-C3.txt’
#
# data_PTCDI-C3.txt   100%[===================>]   4,14K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-04-04 10:39:38 (35,6 MB/s) - ‘./exp_data/data_PTCDI-C3.txt’ saved [4239/4239]
#
# data_PTCDI-C3.txt

# %%
data = np.loadtxt("exp_data/data_PTCDI-C3.txt", delimiter="\t", skiprows=1)
q_exp = data[..., 0]
curve_exp = data[..., 1]

print(curve_exp.shape, q_exp.shape, q_exp.min(), q_exp.max())
# Out:
# (141,) (141,) 0.0142368058 0.213456644

# %% [markdown]
# We interpolate the reflectivity curve to the q points the model was trained on:

# %%
q_model = inference_model.trainer.loader.q_generator.q.cpu().numpy()
exp_curve_interp = interp_reflectivity(q_model, q_exp, curve_exp)

print(exp_curve_interp.shape)
# Out:
# (128,)

# %% [markdown]
# This is a measurement for a two-layer film in which we have some prior knowlede about the investigated system. We know the substrate is silicon on top of which sits a thin silicon oxide layer, followed by a perylene diimide (PTCDI-C3) layer. Thus, we can set narrow prior bounds for the scattering length densities (around known value for these materials) and for the thickness of the silicon oxide layer, but we set wide prior bounds for the roughnesses and for the thickness of the perylene diimide layer. We specify the prior bounds for the parameters as a list of tuples `(min_prior_bound, max_prior_bound)`.

# %%
prior_bounds = [
    (1.0, 400.0),
    (1.0, 10.0),  # layer thicknesses (top to bottom)
    (0.0, 20.0),
    (0.0, 15.0),
    (0.0, 15.0),  # interlayer roughnesses (top to bottom)
    (10.0, 13.0),
    (20.0, 21.0),
    (20.0, 21.0),
]  # real layer slds (top to bottom)

# %% [markdown]
# Now, we can call the `predict` method of the inference model and provide as input the reflectivity curve and the prior bounds in order to obtain the neural network predictions. If the `clip_prediction` argument is `True`, the predictions are clipped to ensure they are not outside the interval defined by the prior bounds. If the `polish_prediction` argument is `True`, the predictions are further polished using a conventional least mean squares (LMS) fit (*currently only available for the standard box-model parameterization*). Additionally,  if `fit_growth` is also `True`, an additional parameter is introduced during the LMS polishing to account for the change in the thickness of the upper layer during the in-situ measurement of the reflectivity curve during film deposition (necessary when the aquisition rate is slow compared to the growth rate), the maximum possible change being given by the `max_d_change` argument. If the `use_q_shift` argument is `True`, the prediction is performed for a batch of slightly shifted versions of the input curve and the best result is returned, which is meant to mitigate the influence of imperfect sample alignment, as introduced in Greco et al. (*applicable only for models with fixed q-discretization*). The method returns a dictionary containing the predicted parameters (both as a BasicParams object and as a Numpy array). If `calc_pred_curve` is `True`, the reflectivity curve corresponding to the predicted parameters is also computed and added to the dictionary.

# %%
prediction_dict = inference_model.predict(
    reflectivity_curve=exp_curve_interp,
    prior_bounds=prior_bounds,
    clip_prediction=False,
    polish_prediction=True,
    use_q_shift=False,
    calc_pred_curve=True,
)
print(prediction_dict.keys())


pred_params = prediction_dict["predicted_params_array"]
pred_curve = prediction_dict["predicted_curve"]
# Out:
# dict_keys(['predicted_params_object', 'predicted_params_array', 'param_names', 'predicted_curve', 'polished_params_array', 'polished_curve'])

# %%
n_layers = inference_model.trainer.loader.prior_sampler.max_num_layers
for param_name, pred_param_val, polished_param_val in zip(
    prediction_dict["param_names"],
    pred_params,
    prediction_dict["polished_params_array"],
):
    print(
        f"{param_name.ljust(14)} -> Predicted: {pred_param_val:.2f}       Polished: {polished_param_val:.2f}"
    )
# Out:
# Thickness L2   -> Predicted: 194.77       Polished: 188.19
# Thickness L1   -> Predicted: 13.28       Polished: 10.00
# Roughness L2   -> Predicted: 19.61       Polished: 20.00
# Roughness L1   -> Predicted: 4.74       Polished: 4.55
# Roughness sub  -> Predicted: 8.11       Polished: 5.51
# SLD L2         -> Predicted: 10.87       Polished: 11.66
# SLD L1         -> Predicted: 20.43       Polished: 21.00
# SLD sub        -> Predicted: 20.37       Polished: 20.51

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 8))
ax.set_yscale("log")
ax.set_ylim(0.5e-10, 5)
ax.set_xlabel("q [$Å^{-1}$]", fontsize=20)
ax.set_ylabel("R(q)", fontsize=20)
ax.tick_params(axis="both", which="major", labelsize=15)
ax.tick_params(axis="both", which="minor", labelsize=15)
y_tick_locations = [10 ** (-2 * i) for i in range(6)]
ax.yaxis.set_major_locator(plt.FixedLocator(y_tick_locations))

ax.scatter(q_model, exp_curve_interp, c="g", s=2, label="interp exp. curve")
ax.plot(q_model, pred_curve, c="r", lw=1, label="pred. curve")
ax.plot(
    q_model,
    prediction_dict["polished_curve"],
    c="orange",
    lw=1,
    label="polished pred. curve",
)

ax.legend(loc="upper right", fontsize=14);
